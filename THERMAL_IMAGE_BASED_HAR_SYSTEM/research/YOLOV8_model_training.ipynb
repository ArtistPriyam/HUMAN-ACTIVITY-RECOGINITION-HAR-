# %% [markdown]
# # IMPORTS

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# %pwd

# %%
import os
os.chdir("../")

# %%
# %pwd

# %%
pip install ultralytics

# %% [markdown]
# # CONFIG CLASS

# %%
from pathlib import Path
from ultralytics import YOLO
import torch

# === Define Paths ===
ROOT = Path.cwd()
CKPT = ROOT / "artifacts" / "model" / "openthermalpose_yolov8_pose" / "weights" / "last.pt"
DATA = ROOT / "artifacts" / "OPEN_THERMAL_IMAGE" / "openthermalpose.yaml"
TRAIN_PATH = Path("/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/train/images")
VAL_PATH = Path("/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images")

# %%
from pathlib import Path

class Config:
    def __init__(self):
        #self.dataset_path = Path("../artifacts/OPEN_THERMAL_IMAGE").resolve()
        self.yaml_path = DATA
        self.model_save_dir = Path("../artifacts/model/openthermalpose").resolve()
        self.model_save_dir.mkdir(parents=True, exist_ok=True)

        self.epochs = 10
        self.img_size = 640
        self.batch_size = 8
        self.learning_rate = 0.001
        self.num_keypoints = 17
        self.device = "cpu"  # or "cuda" if GPU available

# %%
import yaml

# %%
def create_yaml(cfg: Config):
    train_images = TRAIN_PATH
    val_images = VAL_PATH

    data_yaml = {
        'train': str(train_images),
        'val': str(val_images),
        'nc': 1,
        'names': ['person'],
        'keypoints': [f'kp{i}' for i in range(cfg.num_keypoints)],
        'kpt_shape': [cfg.num_keypoints, 3]  # important for pose!
    }

    with open(cfg.yaml_path, "w") as f:
        yaml.dump(data_yaml, f)
    print(f"Dataset YAML with kpt_shape created at {cfg.yaml_path}")

# %% [markdown]
# # TRAINING CLASS

# %%
from pathlib import Path

dataset_folder = Path("./artifacts/OPEN_THERMAL_IMAGE").resolve()
print("Resolved dataset folder:", dataset_folder)

train_images = dataset_folder / "train" / "images"
val_images = dataset_folder / "val" / "images"

print("Train Path:", train_images, "Exists:", train_images.exists())
print("Val Path:", val_images, "Exists:", val_images.exists())

# %%
from pathlib import Path
import yaml

def create_openthermalpose_yaml(dataset_dir: str, num_keypoints=17):
    dataset_path = Path(dataset_dir).resolve()
    train_images = dataset_path / "train" / "images"
    val_images = dataset_path / "val" / "images"

    assert train_images.exists(), f"Train images folder not found: {train_images}"
    assert val_images.exists(), f"Val images folder not found: {val_images}"

    data_yaml = {
        'train': str(train_images),
        'val': str(val_images),
        'nc': 1,  # number of classes (person)
        'names': ['person'],
        'keypoints': [f'kp{i}' for i in range(num_keypoints)]
    }

    yaml_file = dataset_path / "openthermalpose.yaml"
    with open(yaml_file, "w") as f:
        yaml.dump(data_yaml, f)

    print(f"YOLOv8 dataset yaml file created at: {yaml_file}")
    return yaml_file

# Example usage
#dataset_folder = "../artifacts/OPEN_THERMAL_IMAGE"  # relative path from your notebook
yaml_path = create_openthermalpose_yaml(dataset_folder)

# %%
from ultralytics import YOLO

class YOLOv8PoseTrainer:
    def __init__(self, cfg: Config):
        self.cfg = cfg
        self.model = YOLO("yolov8n-pose.pt")  # pre-trained pose model checkpoint

    def train(self):
        results = self.model.train(
            data=str(self.cfg.yaml_path),
            epochs=self.cfg.epochs,
            imgsz=self.cfg.img_size,
            batch=self.cfg.batch_size,
            lr0=self.cfg.learning_rate,
            device=self.cfg.device,
            name="openthermalpose_yolov8_pose",
            project=str(self.cfg.model_save_dir.parent),  # save in 'artifacts/model/'
            exist_ok=True,
            verbose=True
        )
        print("Training complete.")
        # Save best weights manually if you want
        weights_path = self.cfg.model_save_dir / "best.pt"
        self.model.model.save(weights_path)
        print(f"Model saved to {weights_path}")
        return results

# %%
class YOLOv8PoseEvaluator:
    def __init__(self, cfg: Config, model_path: Path):
        self.cfg = cfg
        self.model = YOLO(str(model_path))

    def evaluate(self):
        metrics = self.model.val(
            data=str(self.cfg.yaml_path),
            imgsz=self.cfg.img_size,
            device=self.cfg.device,
            batch=self.cfg.batch_size,
            verbose=True
        )
        print("Evaluation complete.")
        print(metrics)
        return metrics

# %% [markdown]
# # MAIN PIPELINE

# %%
def main():
    cfg = Config()
    create_yaml(cfg)

    trainer = YOLOv8PoseTrainer(cfg)
    trainer.train()

    model_path = cfg.model_save_dir / "best.pt"
    evaluator = YOLOv8PoseEvaluator(cfg, model_path)
    evaluator.evaluate()

if __name__ == "__main__":
    main()

# %%
from pathlib import Path
print(Path("artifacts/OPEN_THERMAL_IMAGE/openthermalpose.yaml").resolve().exists())

# %% [markdown]
# # code for resuming training

# %%
from pathlib import Path
from ultralytics import YOLO

ROOT = Path.cwd()
CKPT = ROOT / "artifacts" / "model" / "openthermalpose_yolov8_pose" / "weights" / "last.pt"
DATA = ROOT / "artifacts" / "OPEN_THERMAL_IMAGE" / "openthermalpose2.yaml"

print("📁 ROOT dir:", ROOT)
print("🔍 Looking for checkpoint at:", CKPT)
print("✅ Exists:", CKPT.exists())

if CKPT.exists():
    print(f"✅ Resuming from checkpoint: {CKPT}")
    model = YOLO(str(CKPT))
    resume_flag = True
else:
    raise FileNotFoundError(f"❌ Checkpoint not found at: {CKPT}")

# === Dataset Paths from YAML ===
train_path = Path("/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/train/images")
val_path = Path("/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images")

# === Check if dataset paths exist ===
print(f"📁 Checking if training images path exists: {train_path} -> {train_path.exists()}")
print(f"📁 Checking if validation images path exists: {val_path} -> {val_path.exists()}")

if not train_path.exists():
    raise FileNotFoundError(f"❌ Training path not found: {train_path}")

if not val_path.exists():
    raise FileNotFoundError(f"❌ Validation path not found: {val_path}")
# Out:
# 📁 ROOT dir: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset
# 🔍 Looking for checkpoint at: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/model/openthermalpose_yolov8_pose/weights/last.pt
# ✅ Exists: True
# ✅ Resuming from checkpoint: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/model/openthermalpose_yolov8_pose/weights/last.pt

# %%
from pathlib import Path
from ultralytics import YOLO
import torch

# === Define Paths ===
ROOT = Path.cwd()
CKPT = ROOT / "artifacts" / "model" / "openthermalpose_yolov8_pose" / "weights" / "last.pt"
DATA = ROOT / "artifacts" / "OPEN_THERMAL_IMAGE" / "openthermalpose2.yaml"
TRAIN_PATH = Path("/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/train/images")
VAL_PATH = Path("/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images")

# === Detect best available device ===
if torch.backends.mps.is_available():
    DEVICE = "mps"
elif torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"

# === Checkpoint & Dataset Path Validations ===
print(f"📂 ROOT dir: {ROOT}")
print(f"🔍 Looking for checkpoint at: {CKPT}")
print(f"✅ Checkpoint exists: {CKPT.exists()}")
print(f"📁 Train path exists: {TRAIN_PATH.exists()}")
print(f"📁 Val path exists: {VAL_PATH.exists()}")

if not TRAIN_PATH.exists() or not VAL_PATH.exists():
    raise FileNotFoundError("❌ One or both dataset paths do not exist. Please check train/val image folders.")

# === Load model ===
try:
    if CKPT.exists():
        print(f"✅ Resuming from checkpoint: {CKPT}")
        model = YOLO(str(CKPT))
        resume_flag = True
    else:
        raise FileNotFoundError(f"❌ Checkpoint not found: {CKPT}")
except Exception as e:
    print(f"🚨 Error loading checkpoint: {e}")
    print("⚠️ Falling back to base YOLOv8n-pose model...")
    model = YOLO("yolov8n-pose.pt")
    resume_flag = False

# === Start Training ===
try:
    model.train(
        data=str(DATA),
        epochs=10,
        resume=resume_flag,
        device=DEVICE,
        project=str(ROOT / "artifacts/model"),
        name="openthermalpose_yolov8_pose"
    )
except RuntimeError as e:
    if "knet" in str(e).lower():
        print("❌ knet error: This may be due to unsupported GPU backend.")
        print("👉 Try setting `device='cpu'` or rechecking your PyTorch/MPS environment.")
    raise e
# Out:
# 📂 ROOT dir: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset
# 🔍 Looking for checkpoint at: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/model/openthermalpose_yolov8_pose/weights/last.pt
# ✅ Checkpoint exists: True
# 📁 Train path exists: True
# 📁 Val path exists: True
# ✅ Resuming from checkpoint: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/model/openthermalpose_yolov8_pose/weights/last.pt
# Ultralytics 8.3.152 🚀 Python-3.12.7 torch-2.7.0 MPS (Apple M2)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/openthermalpose.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=True, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/model/openthermalpose_yolov8_pose/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=openthermalpose_yolov8_pose, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/model, rect=False, resume=/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/model/openthermalpose_yolov8_pose/weights/last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/model/openthermalpose_yolov8_pose, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# WARNING ⚠️ Apple MPS known Pose bug. Recommend 'device=cpu' for Pose models. See https://github.com/ultralytics/ultralytics/issues/4031.
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[17, 2]
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    923785  ultralytics.nn.modules.head.Pose             [1, [17, 2], [64, 128, 256]]
# YOLOv8n-pose summary: 144 layers, 3,183,321 parameters, 3,183,305 gradients, 8.8 GFLOPs
#
# Transferred 361/397 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 384.7±85.9 MB/s, size: 160.2 KB)
# train: Scanning /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/train/labels.cache... 8846 images, 0 backgrounds, 0 corrupt: 100%|██████████| 8846/8846 [00:00<?, ?it/s]
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 373.1±139.6 MB/s, size: 157.1 KB)
# val: Scanning /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/labels.cache... 934 images, 0 backgrounds, 934 corrupt: 100%|██████████| 934/934 [00:00<?, ?it/s]
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_1_1_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_1_2_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_1_3_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_1_4_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_1_5_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_1_6_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_1_7_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_1_8_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_1_9_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_2_1_143_100_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_2_2_108_101_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_2_3_118_101_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_2_4_102_34_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_2_5_122_31_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_2_6_204_104_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_2_7_132_61_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_2_8_157_26_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_1_2_9_238_2_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_1_1_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_1_2_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_1_3_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_1_4_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_1_5_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_1_6_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_1_7_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_1_8_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_1_9_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_2_1_103_29_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_2_2_140_47_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_2_3_191_30_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_2_4_117_102_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_2_5_169_31_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_2_6_155_102_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_2_7_152_17_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_2_8_120_29_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/131_2_2_9_164_39_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_1_1_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_1_2_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_1_3_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_1_4_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_1_5_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_1_6_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_1_7_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_1_8_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_1_9_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_2_1_107_112_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_2_2_15_108_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_2_3_123_26_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_2_4_160_30_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_2_5_151_51_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_2_6_176_27_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_2_7_124_118_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_2_8_10_105_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_1_2_9_136_49_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_1_1_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_1_2_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_1_3_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_1_4_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_1_5_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_1_6_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_1_7_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_1_8_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_1_9_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_2_1_202_100_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_2_2_116_31_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_2_3_113_45_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_2_4_16_101_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_2_5_129_102_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_2_6_109_100_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_2_7_134_47_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_2_8_140_29_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/132_2_2_9_186_12_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_1_1_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_1_2_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_1_3_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_1_4_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_1_5_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_1_6_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_1_7_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_1_8_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_1_9_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_2_1_191_32_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_2_2_149_30_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_2_3_128_100_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_2_4_115_28_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_2_5_101_2_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_2_6_110_28_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_2_7_100_101_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_2_8_243_101_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_1_2_9_119_23_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_1_1_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_1_2_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_1_3_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_1_4_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_1_5_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_1_6_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_1_7_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_1_8_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_1_9_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_2_1_135_25_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_2_2_155_100_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_2_3_200_2_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_2_4_105_25_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_2_5_131_28_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_2_6_188_28_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_2_7_108_21_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_2_8_171_100_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/133_2_2_9_122_100_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_1_1_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_1_2_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_1_3_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_1_4_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_1_5_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_1_6_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_1_7_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_1_8_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_1_9_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_2_1_112_23_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_2_2_117_22_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_2_3_173_20_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_2_4_12_30_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_2_5_175_22_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_2_6_13_102_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_2_7_156_22_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_2_8_225_101_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_1_2_9_103_30_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_1_1_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_1_2_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_1_3_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_1_4_256_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_1_5_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_1_6_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_1_7_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_1_8_713_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_1_9_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_2_1_161_21_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_2_2_104_109_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_2_3_118_105_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_2_4_102_23_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_2_5_137_102_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_2_6_121_101_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_2_7_111_101_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_2_8_106_108_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/134_2_2_9_102_26_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_1_1_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_1_2_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_1_3_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_1_4_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_1_5_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_1_6_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_1_7_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_1_8_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_1_9_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_2_1_220_37_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_2_2_113_41_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_2_3_129_103_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_2_4_131_58_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_2_5_136_41_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_2_6_109_45_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_2_7_175_39_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_2_8_117_36_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_1_2_9_168_50_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_1_1_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_1_2_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_1_3_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_1_4_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_1_5_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_1_6_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_1_7_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_1_8_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_1_9_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_2_1_202_109_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_2_2_33_103_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_2_3_147_36_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_2_4_115_31_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_2_5_215_100_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_2_6_11_47_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_2_7_10_32_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_2_8_152_53_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/135_2_2_9_139_3_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_1_1_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_1_2_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_1_3_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_1_4_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_1_5_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_1_6_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_1_7_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_1_8_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_1_9_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_2_1_146_33_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_2_2_13_184_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_2_3_12_3_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_2_4_127_107_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_2_5_125_104_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_2_6_104_111_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_2_7_162_45_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_2_8_118_106_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_1_2_9_110_34_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_1_1_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_1_2_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_1_3_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_1_4_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_1_5_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_1_6_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_1_7_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_1_8_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_1_9_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_2_1_163_40_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_2_2_108_28_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_2_3_158_30_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_2_4_100_136_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_2_5_15_51_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_2_6_116_31_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_2_7_164_28_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_2_8_126_101_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/136_2_2_9_106_111_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_1_1_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_1_2_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_1_3_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_1_4_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_1_5_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_1_6_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_1_7_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_1_8_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_1_9_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_2_1_187_102_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_2_2_105_10_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_2_3_176_109_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_2_4_135_113_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_2_5_132_103_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_2_6_114_110_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_2_7_101_35_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_2_8_143_106_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_1_2_9_103_38_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_2_1_1_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_2_1_2_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_2_1_3_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_2_1_4_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_2_1_5_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_2_1_6_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_2_1_7_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_2_1_8_450_1.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/137_2_1_9_1_1.png: ignoring corrupt image/label: labels require 39 columns each
# ...
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3230.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3231.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3232.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3233.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3234.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3235.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3236.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3237.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3238.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3239.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3240.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3241.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3242.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3243.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3244.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3245.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3246.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3247.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3248.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3249.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3250.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3251.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3252.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3253.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3254.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3255.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3256.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3257.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3258.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3259.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3260.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3261.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3262.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3263.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3264.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3265.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3266.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3267.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3268.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3269.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3270.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3271.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3272.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3273.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3274.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3275.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3276.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3277.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3278.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3279.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3280.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3281.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3282.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3283.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3284.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3285.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3286.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3287.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3288.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3289.png: ignoring corrupt image/label: labels require 39 columns each
# val: /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/images/3290.png: ignoring corrupt image/label: labels require 39 columns each
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 58
#      56     print("❌ knet error: This may be due to unsupported GPU backend.")
#      57     print("👉 Try setting `device='cpu'` or rechecking your PyTorch/MPS environment.")
# ---> 58 raise e
#
# Cell In[19], line 46
#      44 # === Start Training ===
#      45 try:
# ---> 46     model.train(
#      47         data=str(DATA),
#      48         epochs=10,
#      49         resume=resume_flag,
#      50         device=DEVICE,
#      51         project=str(ROOT / "artifacts/model"),
#      52         name="openthermalpose_yolov8_pose"
#      53     )
#      54 except RuntimeError as e:
#      55     if "knet" in str(e).lower():
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/model.py:797, in Model.train(self, trainer, **kwargs)
#     794     self.model = self.trainer.model
#     796 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 797 self.trainer.train()
#     798 # Update model and cfg after training
#     799 if RANK in {-1, 0}:
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/trainer.py:227, in BaseTrainer.train(self)
#     224         ddp_cleanup(self, str(file))
#     226 else:
# --> 227     self._do_train(world_size)
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/trainer.py:348, in BaseTrainer._do_train(self, world_size)
#     346 if world_size > 1:
#     347     self._setup_ddp(world_size)
# --> 348 self._setup_train(world_size)
#     350 nb = len(self.train_loader)  # number of batches
#     351 nw = max(round(self.args.warmup_epochs * nb), 100) if self.args.warmup_epochs > 0 else -1  # warmup iterations
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/trainer.py:312, in BaseTrainer._setup_train(self, world_size)
#     307 self.train_loader = self.get_dataloader(
#     308     self.data["train"], batch_size=batch_size, rank=LOCAL_RANK, mode="train"
#     309 )
#     310 if RANK in {-1, 0}:
#     311     # Note: When training DOTA dataset, double batch size could get OOM on images with >2000 objects.
# --> 312     self.test_loader = self.get_dataloader(
#     313         self.data.get("val") or self.data.get("test"),
#     314         batch_size=batch_size if self.args.task == "obb" else batch_size * 2,
#     315         rank=-1,
#     316         mode="val",
#     317     )
#     318     self.validator = self.get_validator()
#     319     metric_keys = self.validator.metrics.keys + self.label_loss_items(prefix="val")
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/models/yolo/detect/train.py:83, in DetectionTrainer.get_dataloader(self, dataset_path, batch_size, rank, mode)
#      81 assert mode in {"train", "val"}, f"Mode must be 'train' or 'val', not {mode}."
#      82 with torch_distributed_zero_first(rank):  # init dataset *.cache only once if DDP
# ---> 83     dataset = self.build_dataset(dataset_path, mode, batch_size)
#      84 shuffle = mode == "train"
#      85 if getattr(dataset, "rect", False) and shuffle:
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/models/yolo/detect/train.py:66, in DetectionTrainer.build_dataset(self, img_path, mode, batch)
#      54 """
#      55 Build YOLO Dataset for training or validation.
#      56
#    (...)
#      63     (Dataset): YOLO dataset object configured for the specified mode.
#      64 """
#      65 gs = max(int(de_parallel(self.model).stride.max() if self.model else 0), 32)
# ---> 66 return build_yolo_dataset(self.args, img_path, batch, self.data, mode=mode, rect=mode == "val", stride=gs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/data/build.py:117, in build_yolo_dataset(cfg, img_path, batch, data, mode, rect, stride, multi_modal)
#     115 """Build and return a YOLO dataset based on configuration parameters."""
#     116 dataset = YOLOMultiModalDataset if multi_modal else YOLODataset
# --> 117 return dataset(
#     118     img_path=img_path,
#     119     imgsz=cfg.imgsz,
#     120     batch_size=batch,
#     121     augment=mode == "train",  # augmentation
#     122     hyp=cfg,  # TODO: probably add a get_hyps_from_cfg function
#     123     rect=cfg.rect or rect,  # rectangular batches
#     124     cache=cfg.cache or None,
#     125     single_cls=cfg.single_cls or False,
#     126     stride=int(stride),
#     127     pad=0.0 if mode == "train" else 0.5,
#     128     prefix=colorstr(f"{mode}: "),
#     129     task=cfg.task,
#     130     classes=cfg.classes,
#     131     data=data,
#     132     fraction=cfg.fraction if mode == "train" else 1.0,
#     133 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/data/dataset.py:88, in YOLODataset.__init__(self, data, task, *args, **kwargs)
#      86 self.data = data
#      87 assert not (self.use_segments and self.use_keypoints), "Can not use both segments and keypoints."
# ---> 88 super().__init__(*args, channels=self.data["channels"], **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/data/base.py:116, in BaseDataset.__init__(self, img_path, imgsz, cache, augment, hyp, prefix, rect, batch_size, stride, pad, single_cls, classes, fraction, channels)
#     114 self.cv2_flag = cv2.IMREAD_GRAYSCALE if channels == 1 else cv2.IMREAD_COLOR
#     115 self.im_files = self.get_img_files(self.img_path)
# --> 116 self.labels = self.get_labels()
#     117 self.update_labels(include_class=classes)  # single_cls and include_class
#     118 self.ni = len(self.labels)  # number of images
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/data/dataset.py:188, in YOLODataset.get_labels(self)
#     186 labels = cache["labels"]
#     187 if not labels:
# --> 188     raise RuntimeError(
#     189         f"No valid images found in {cache_path}. Images with incorrectly formatted labels are ignored. {HELP_URL}"
#     190     )
#     191 self.im_files = [lb["im_file"] for lb in labels]  # update im_files
#     193 # Check if the dataset is all boxes or all segments
#
# RuntimeError: No valid images found in /Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/labels.cache. Images with incorrectly formatted labels are ignored. See https://docs.ultralytics.com/datasets for dataset formatting guidance.

# %%
import os
from pathlib import Path

# Define path to the val label directory
label_root = Path("/Users/priyam/DIL_LAB/HAR_HEAT_IMAGEdataset/artifacts/OPEN_THERMAL_IMAGE/val/labels")

for label_path in label_root.glob("*.txt"):
    with open(label_path) as f:
        lines = f.readlines()

    new_lines = []
    modified = False

    for line in lines:
        parts = line.strip().split()
        try:
            floats = list(map(float, parts))
            class_id = int(floats[0])
            coords = floats[1:]

            # Clamp each coordinate to [0.0, 1.0]
            normalized_coords = [min(max(c, 0.0), 1.0) for c in coords]
            if coords != normalized_coords:
                modified = True

            new_line = f"{class_id} " + " ".join(f"{val:.6f}" for val in normalized_coords)
            new_lines.append(new_line + "\n")
        except:
            print(f"⚠️ Skipping invalid line in {label_path.name}: {line.strip()}")

    if modified:
        with open(label_path, "w") as f:
            f.writelines(new_lines)
        print(f"🔧 Normalized: {label_path.name}")
